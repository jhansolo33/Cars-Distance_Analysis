# %%
import pandas as pd
from pathlib import Path
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r"C:\Users\Pluto\Class\Cars24Final\cars_24_Combination.csv")[:-2]
X = df.iloc[:].values.reshape(-1,1)
df.head()
# Out:
#      Price  Distance
# 0   514000      3878
# 1   674000     32041
# 2  1952000     96339
# 3   690000     51718
# 4   526000     19811

# %%
plt.scatter(df.Distance,df.Price)
plt.xlabel('Price')
plt.ylabel('Distance')
plt.show()

# %%
#Split data into training and testing
# Create our features
dfd = df.drop(columns="Price")
X = pd.get_dummies(dfd, columns=["Distance"])
-0p
y = df["Price"]
y
# Out:
# 0        514000
# 1        674000
# 2       1952000
# 3        690000
# 4        526000
#          ...
# 8008     554000
# 8009     821000
# 8010     292000
# 8011     534000
# 8012     424000
# Name: Price, Length: 8013, dtype: int64

# %%
y.value_counts()
# Out:
# 505000     25
# 483000     24
# 606000     24
# 613000     24
# 535000     23
#            ..
# 1952000     1
# 472650      1
# 489650      1
# 1204000     1
# 1285000     1
# Name: Price, Length: 1354, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=1)  
Counter(y_test)
# Out:
# Counter({563000: 5,
#          714000: 4,
#          363000: 4,
#          307000: 6,
#          757000: 4,
#          650000: 8,
#          360000: 1,
#          362000: 3,
#          754000: 1,
#          427000: 2,
#          660000: 2,
#          525000: 9,
#          1813000: 1,
#          649000: 5,
#          438000: 4,
#          455000: 3,
#          301000: 3,
#          676000: 4,
#          596000: 6,
#          991000: 2,
#          964000: 2,
#          224000: 4,
#          378000: 4,
#          673000: 6,
#          580000: 6,
#          313000: 8,
#          433000: 4,
#          405500: 1,
#          577000: 8,
#          481000: 4,
#          227000: 4,
#          1355000: 1,
#          1013000: 1,
#          1043000: 1,
#          370000: 5,
#          522000: 6,
#          498000: 8,
#          837000: 2,
#          396000: 7,
#          620000: 5,
#          839000: 2,
#          628000: 6,
#          509200: 1,
#          400000: 3,
#          443000: 5,
# ...

# %%
#Fitting Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression().fit(X_train, y_train)

# %%
#viz training set results
viz_train = plt
viz_train.plot(X_train, regressor.predict(X_train), color='blue')
viz_train.title('Price VS Distance')
viz_train.xlabel('Distance')
viz_train.ylabel('Price')
viz_train.show()

#viz test set results
viz_test = plt
viz_test.plot(X_test, regressor.predict(X_train), color='blue')
viz_test.title('Price VS Distance (Test set)')
viz_test.xlabel('Distance')
viz_test.ylabel('Price')
viz_test.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_120220\3313142643.py in <module>
#      11 viz_test = plt
#      12 #viz_test.scatter(X_test, y_test, color='red')
# ---> 13 viz_test.plot(X_test, regressor.predict(X_train), color='blue')
#      14 viz_test.title('Price VS Distance (Test set)')
#      15 viz_test.xlabel('Distance')
#
# ~\anaconda3\envs\mlenv\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
# -> 2771         **({"data": data} if data is not None else {}), **kwargs)
#    2772
#    2773
#
# ~\anaconda3\envs\mlenv\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...
